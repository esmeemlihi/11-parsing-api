# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
#url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'
ur_l = "http://api.stackexchange.com/2.2/questions?todate=1571011200&order=desc&sort=activity&tagged=python&site=stackoverflow"
url_2 = "http://www.recipepuppy.com/api/?i=onions,garlic&q=omelet&p=3"

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
# Your code

response = requests.get(url_2)    
results_url = response.json()
results_url
# Out:
# {'title': 'Recipe Puppy',
#  'version': 0.1,
#  'href': 'http://www.recipepuppy.com/',
#  'results': [{'title': 'Vegetable-Pasta Oven Omelet',
#    'href': 'http://find.myrecipes.com/recipes/recipefinder.dyn?action=displayRecipe&recipe_id=520763',
#    'ingredients': 'tomato, onions, red pepper, garlic, olive oil, zucchini, cream cheese, vermicelli, eggs, parmesan cheese, milk, italian seasoning, salt, black pepper',
#    'thumbnail': 'http://img.recipepuppy.com/560556.jpg'},
#   {'title': 'Roasted Pepper and Bacon Omelet',
#    'href': 'http://www.bigoven.com/43919-Roasted-Pepper-and-Bacon-Omelet-recipe.html',
#    'ingredients': 'eggs, salt, black pepper, butter, black pepper, bacon, onions, garlic, roasted red peppers, oregano, black pepper',
#    'thumbnail': ''},
#   {'title': '\nBroccoli Oven Omelet Recipe\n\n',
#    'href': 'http://cookeatshare.com/recipes/broccoli-oven-omelet-92851',
#    'ingredients': 'eggs, broccoli, onions, parmesan cheese, lowfat milk, salt, basil, garlic, tomato, parmesan cheese',
#    'thumbnail': ''},
#   {'title': 'Eggplant Omelet with Coriander and Caraway',
#    'href': 'http://www.epicurious.com/recipes/food/views/Eggplant-Omelet-with-Coriander-and-Caraway-306',
#    'ingredients': 'caraway seed, coriander, eggplant, eggs, garlic, lemon, olive oil, onions, black pepper, salt',
#    'thumbnail': ''},
#   {'title': 'Eggplant Omelet with Coriander And Caraway',
#    'href': 'http://www.bigoven.com/143831-Eggplant-Omelet-with-Coriander-And-Caraway-recipe.html',
#    'ingredients': 'eggplant, olive oil, onions, garlic, egg, caraway seed, coriander, salt, black pepper, lemon',
#    'thumbnail': ''},
#   {'title': 'Broccoli and Cheese Omelet',
#    'href': 'http://www.bigoven.com/45151-Broccoli-and-Cheese-Omelet-recipe.html',
#    'ingredients': 'onions, garlic, chicken broth, cottage cheese, oregano, black pepper, egg substitute, bread, mozzarella cheese, butter',
#    'thumbnail': ''},
#   {'title': 'Chard And Onion Omelet',
#    'href': 'http://www.bigoven.com/149383-Chard-And-Onion-Omelet-recipe.html',
#    'ingredients': 'olive oil, onions, leaves, garlic, eggs, parsley, basil, thyme, gruyere cheese, parmesan cheese',
#    'thumbnail': ''},
#   {'title': 'Picnic Omelet Squares Recipe',
#    'href': 'http://www.cdkitchen.com/recipes/recs/2184/Picnic-Omelet-Squares99498.shtml',
#    'ingredients': 'eggs, garlic, parmesan cheese, olive oil, onions, peas, potato, red pepper, salt, tomato, zucchini',
#    'thumbnail': ''},
#   {'title': 'Spanish Omelet',
#    'href': 'http://www.cooks.com/rec/view/0,185,153160-249194,00.html',
#    'ingredients': 'vegetable oil, green pepper, onions, water, milk, eggs, black pepper, mushroom, garlic, salt, chili powder',
#    'thumbnail': ''},
#   {'title': 'Onion and Fresh Herb Omelet with Mixed Greens',
#    'href': 'http://find.myrecipes.com/recipes/recipefinder.dyn?action=displayRecipe&recipe_id=1622444',
#    'ingredients': 'egg substitute, milk, parsley, thyme, salt, black pepper, eggs, flour, nonstick cooking spray, onions, garlic, salad greens, salad greens, red wine vinegar, olive oil, goat cheese, almonds',
#    'thumbnail': 'http://img.recipepuppy.com/514820.jpg'}]}

# %%
data = pd.DataFrame(results_url)
data.head()
# Out:
#           title  version                         href  \
# 0  Recipe Puppy      0.1  http://www.recipepuppy.com/
# 1  Recipe Puppy      0.1  http://www.recipepuppy.com/
# 2  Recipe Puppy      0.1  http://www.recipepuppy.com/
# 3  Recipe Puppy      0.1  http://www.recipepuppy.com/
# 4  Recipe Puppy      0.1  http://www.recipepuppy.com/
#
#                                              results
# 0  {'title': 'Vegetable-Pasta Oven Omelet', 'href...
# 1  {'title': 'Roasted Pepper and Bacon Omelet', '...
# 2  {'title': '
# Broccoli Oven Omelet Recipe
#
# ', 'h...
# 3  {'title': 'Eggplant Omelet with Coriander and ...
# 4  {'title': 'Eggplant Omelet with Coriander And ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
nested_columns = ['results']

flat = flatten(data, nested_columns)
flat.head()
# Out:
#           title  version                         href  \
# 0  Recipe Puppy      0.1  http://www.recipepuppy.com/
# 1  Recipe Puppy      0.1  http://www.recipepuppy.com/
# 2  Recipe Puppy      0.1  http://www.recipepuppy.com/
# 3  Recipe Puppy      0.1  http://www.recipepuppy.com/
# 4  Recipe Puppy      0.1  http://www.recipepuppy.com/
#
#                                 results_title  \
# 0                 Vegetable-Pasta Oven Omelet
# 1             Roasted Pepper and Bacon Omelet
# 2           \nBroccoli Oven Omelet Recipe\n\n
# 3  Eggplant Omelet with Coriander and Caraway
# 4  Eggplant Omelet with Coriander And Caraway
#
#                                         results_href  \
# 0  http://find.myrecipes.com/recipes/recipefinder...
# 1  http://www.bigoven.com/43919-Roasted-Pepper-an...
# 2  http://cookeatshare.com/recipes/broccoli-oven-...
# 3  http://www.epicurious.com/recipes/food/views/E...
# 4  http://www.bigoven.com/143831-Eggplant-Omelet-...
#
#                                  results_ingredients  \
# 0  tomato, onions, red pepper, garlic, olive oil,...
# 1  eggs, salt, black pepper, butter, black pepper...
# 2  eggs, broccoli, onions, parmesan cheese, lowfa...
# 3  caraway seed, coriander, eggplant, eggs, garli...
# 4  eggplant, olive oil, onions, garlic, egg, cara...
#
#                        results_thumbnail
# 0  http://img.recipepuppy.com/560556.jpg
# 1
# 2
# 3
# 4

# %%
"""
For example:
http://www.recipepuppy.com/api/?i=onions,garlic&q=omelet&p=3

Optional Parameters:
i : comma delimited ingredients
q : normal search query
p : page
format=xml : if you want xml instead of json

"""

url_3 = "http://www.recipepuppy.com/api/?i=sugar &q=pasta &p=3"

from pandas.io.json import json_normalize
response = requests.get(url_3)
results = response.json()
ls = []
# this is a shorter way to read json files than with flatternm you do not nead to define a function anymore 
flattened_data = json_normalize(results)
#flattened_data2 = json_normalize(results, results)
# hier zie je de kolommen om snel te zien welke nested zijn. In dit geval is het alleen "results"
flattened_data
# Out:
#           title  version                         href  \
# 0  Recipe Puppy      0.1  http://www.recipepuppy.com/
#
#                                              results
# 0  [{'title': 'Sicilian Lentil Pasta Sauce', 'hre...

# %%
# zo kan je de kolom "results" uitvouwen 
flattened_data_1 = json_normalize(flattened_data.results[0])

#flattened_data_2 = json_normalize(flattened_data, ls)

flattened_data_1.head(10)
# Out:
#                                             title  \
# 0                     Sicilian Lentil Pasta Sauce
# 1                  Sweet Garlic Tomato Beef Pasta
# 2                    Vegetable Pasta Sauce Recipe
# 3                         Carls Fresh Pasta Sauce
# 4  Garden Pasta With Shrimp (Or Chicken or Tofu!)
# 5                        Sweet Pasta Salad Recipe
# 6                                Fast Pasta Sauce
# 7                          Tomato Sauce for Pasta
# 8                            Cucumber Pasta Salad
# 9                    Asian Noodle and Pasta Salad
#
#                                                 href  \
# 0  http://allrecipes.com/Recipe/Sicilian-Lentil-P...
# 1  http://allrecipes.com/Recipe/Sweet-Garlic-Toma...
# 2  http://www.grouprecipes.com/1885/vegetable-pas...
# 3  http://www.bigoven.com/53049-Carls-Fresh-Pasta...
# 4  http://www.recipezaar.com/Garden-Pasta-With-Sh...
# 5  http://www.grouprecipes.com/45394/sweet-pasta-...
# 6  http://www.recipezaar.com/Fast-Pasta-Sauce-106631
# 7  http://www.recipezaar.com/Tomato-Sauce-for-Pas...
# 8  http://www.recipezaar.com/Cucumber-Pasta-Salad...
# 9  http://allrecipes.com/Recipe/Asian-Noodle-and-...
#
#                                          ingredients  \
# 0  garlic, lentils, olive oil, onions, water, wat...
# 1  ground beef, beef bouillon granules, black pep...
# 2  black pepper, tomato, corn starch, garlic, but...
# 3  olive oil, onions, garlic, salt, sugar, tomato...
# 4  pasta, red pepper flakes, feta cheese, basil, ...
# 5  black pepper, carrot, white vinegar, mayonnais...
# 6  bay leaf, tomato, basil, oregano, black pepper...
# 7  celery, cinnamon, basil, garlic, nutmeg, onion...
# 8  pasta, coleslaw, cucumber, green onion, red wi...
# 9  carrot, red onions, pasta, sugar snap pea, veg...
#
#                                thumbnail
# 0   http://img.recipepuppy.com/20891.jpg
# 1     http://img.recipepuppy.com/837.jpg
# 2  http://img.recipepuppy.com/297087.jpg
# 3  http://img.recipepuppy.com/570223.jpg
# 4  http://img.recipepuppy.com/638433.jpg
# 5
# 6  http://img.recipepuppy.com/556048.jpg
# 7   http://img.recipepuppy.com/41169.jpg
# 8
# 9

# %%
url_beer = "https://api.openbrewerydb.org/breweries"

url_jokes = "https://api.icndb.com"

from pandas.io.json import json_normalize
response = requests.get(url_beer)
results = response.json()

beer_data = json_normalize(results)

beer_data
# Out:
#      id                                         name brewery_type  \
# 0     2                          Avondale Brewing Co        micro
# 1     4             Band of Brothers Brewing Company        micro
# 2    44                             Trim Tab Brewing        micro
# 3    46                         Yellowhammer Brewery        micro
# 4    55                     Bearpaw River Brewing Co        micro
# 5    76                       King Street Brewing Co        micro
# 6    94                                 1912 Brewing        micro
# 7    98                            Bad Water Brewing     contract
# 8   104          BJs Restaurant & Brewery - Chandler      brewpub
# 9   107                            BlackRock Brewers        micro
# 10  127                           Dragoon Brewing Co        micro
# 11  141                 Grand Canyon Brewing Company        micro
# 12  163                          Mudshark Brewing Co        micro
# 13  182                             Richter Aleworks        micro
# 14  187                            SanTan Brewing Co     regional
# 15  198                             State 48 Brewery      brewpub
# 16  219                   Wren House Brewing Company        micro
# 17  225  Brick Oven Pizza Co / Brick & Forge Brewing      brewpub
# 18  235                      Diamond Bear Brewing Co        micro
# 19  247                           Lost Forty Brewing        micro
#
#                                street               city     state  \
# 0                       201 41st St S         Birmingham   Alabama
# 1                       1605 23rd Ave         Tuscaloosa   Alabama
# 2                      2721 5th Ave S         Birmingham   Alabama
# 3                  2600 Clinton Ave W         Huntsville   Alabama
# 4           4605 E Palmer Wasilla Hwy            Wasilla    Alaska
# 5                    9050 King Street          Anchorage    Alaska
# 6          2045 N Forbes Blvd Ste 105             Tucson   Arizona
# 7                    4216 N Brown Ave         Scottsdale   Arizona
# 8                3155 W Chandler Blvd           Chandler   Arizona
# 9        1664 S Research Loop Ste 200             Tucson   Arizona
# 10            1859 W Grant Rd Ste 111             Tucson   Arizona
# 11                     233 W Route 66           Williams   Arizona
# 12                    210 Swanson Ave   Lake Havasu City   Arizona
# 13  8279 W Lake Pleasant Pkwy Ste 110             Peoria   Arizona
# 14                  8 S San Marcos Pl           Chandler   Arizona
# 15                    13823 W Bell Rd           Surprise   Arizona
# 16                     2125 N 24th St            Phoenix   Arizona
# 17                    2410 Linwood Dr          Paragould  Arkansas
# 18                  600 N Broadway St  North Little Rock  Arkansas
# 19                        501 Byrd St        Little Rock  Arkansas
#
#    postal_code        country          longitude          latitude  \
# 0   35222-1932  United States         -86.774322         33.524521
# 1   35401-4653  United States  -87.5621551272424  33.1984907123707
# 2   35233-3401  United States  -86.7914000624146  33.5128492349817
# 3   35805-3046  United States        -86.5932014        34.7277523
# 4   99654-7679  United States       -149.4127103        61.5752695
# 5        99515  United States  -149.879076042937  61.1384893547315
# 6   85745-1444  United States  -110.992750525872  32.2467372722906
# 7   85251-3914  United States  -111.924474347826  33.4972615652174
# 8   85226-5175  United States        -111.911126        33.3053455
# 9   85710-6767  United States  -110.821778571134   32.201608314954
# 10  85745-1214  United States  -111.005452051979  32.2504946147872
# 11  86046-2530  United States       -112.1892168        35.2500282
# 12  86403-0966  United States  -114.342433477881  34.4689736300844
# 13  85382-7434  United States  -112.238054093359  33.6687744976834
# 14  85225-7862  United States       -111.8423459        33.3032436
# 15  85374-3873  United States  -112.357813820157       33.63822125
# 16  85008-2713  United States       -112.0301125         33.516633
# 17  72450-6122  United States  -90.5204797204622  36.0316358142169
# 18  72114-5381  United States  -92.2726892120821  34.7594277548278
# 19       72202  United States         -92.260019         34.742845
#
#          phone                           website_url  \
# 0   2057775456        http://www.avondalebrewing.com
# 1   2052665137      http://www.bandofbrosbrewing.com
# 2   2057030536         http://www.trimtabbrewing.com
# 3   2569755950    http://www.yellowhammerbrewery.com
# 4                     http://bearpawriverbrewing.com
# 5   9073365464      http://www.kingstreetbrewing.com
# 6   5202564851            http://www.1912brewing.com
# 7   5207459175        http://www.badwaterbrewing.com
# 8   4809170631         http://www.bjsrestaurants.com
# 9   5202073203                   http://www.brb.beer
# 10  5203293606         http://www.dragoonbrewing.com
# 11  8005132072   http://www.grandcanyonbrewingco.com
# 12  9284532981      http://www.mudsharkbrewingco.com
# 13  6029086553        http://www.richteraleworks.com
# 14  4809178700          http://www.santanbrewing.com
# 15  6235841095
# 16  6022449184       http://www.wrenhousebrewing.com
# 17  8702364200  http://www.brickovenpizzacompany.com
# 18  5017082739            http://www.diamondbear.com
# 19  5013197275         http://www.lost40brewing.com/
#
#                   updated_at tag_list
# 0   2018-08-23T23:19:57.825Z       []
# 1   2018-08-23T23:19:59.462Z       []
# 2   2018-08-23T23:20:31.423Z       []
# 3   2018-08-23T23:20:33.102Z       []
# 4   2018-08-23T23:20:40.743Z       []
# 5   2018-08-23T23:20:57.179Z       []
# 6   2018-08-23T23:21:11.302Z       []
# 7   2018-08-23T23:21:15.169Z       []
# 8   2018-08-23T23:21:21.165Z       []
# 9   2018-08-23T23:21:23.794Z       []
# 10  2018-08-23T23:21:40.563Z       []
# 11  2018-08-23T23:21:53.397Z       []
# 12  2018-08-23T23:22:12.542Z       []
# 13  2018-08-23T23:22:29.385Z       []
# 14  2018-08-23T23:22:33.482Z       []
# 15  2018-08-23T23:22:41.468Z       []
# 16  2018-08-23T23:22:59.255Z       []
# 17  2018-08-23T23:23:05.438Z       []
# 18  2018-08-23T23:23:14.931Z       []
# 19  2018-08-23T23:23:24.018Z       []

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = requests.get(url)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
